# %% [markdown]
# # Stroke unit services in Samuel-3
#
# Use the SSNAP atlas to check which units offer which services.
#
# SSNAP atlas for stroke units as of November 2025.
#
# Assume that all HASU offer thrombolysis. Only units on the thrombectomy performance map offer thrombectomy.
#
# Plot map of ICBs, mark stroke unit locations, see which units offer thrombolysis and thrombectomy.
#
# Data needed:
# + SSNAP atlas: map of thrombolysis units
# + SSNAP atlas: map of thrombectomy centres
# + Shape file: Integrated Care Boards (ICBs)
# + Shape file: Local Health Boards (LHBs)
# + Coordinates: stroke units
